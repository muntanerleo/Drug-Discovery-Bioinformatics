# %% [markdown]
# # Part 1:
# ## Using the ChEMBL Database
# The chembl database is a database that contains curated bioactivity data of more than 2 million compounds.
#
# I installed the chembl web service package so that i can retrieve bioactivity data from the database.
#
# In this jupyter notebook i will be building a real life data science project. I will be building a machine learning model using the ChEMBL bioactivity data.

# %%
# importing libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Search for target protein
# Essentially this will be the protien that the drug will act on.
#
# Biologically these compounds will come into contact with the protien or organism and induce modulatory activity towards it. It could be to activate the protien/organism.
#
# The code for this section will be like going to the chembl website and searching for a virus in the search bar.

# %%
# TODO: Target search for Leukemia:

# assign new client.target to the target variable
target = new_client.target

# create variable that searches for the desired virus/disease
target_query = target.search('Myeloproliferative leukemia')

# create a target dataframe and assign it the target query as the argument.
targets = pd.DataFrame.from_dict(target_query)

# display the contents of the dataframe
targets

# for this part i will be using the single protein and chimeric protien
# Out:
#                                      cross_references      organism  \
# 0   [{'xref_id': 'P40238', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                  []  Mus musculus
# 2   [{'xref_id': 'Thrombopoietin', 'xref_name': No...  Homo sapiens
# 3                                                  []  Homo sapiens
# 4                                                  []  Homo sapiens
# ..                                                ...           ...
# 58                                                 []  Mus musculus
# 59                                                 []  Homo sapiens
# 60                                                 []  Homo sapiens
# 61                                                 []  Homo sapiens
# 62                                                 []  Homo sapiens
#
#                                             pref_name  score  \
# 0                             Thrombopoietin receptor   26.0
# 1                             Thrombopoietin receptor   26.0
# 2                                      Thrombopoietin   23.0
# 3                           Myeloid leukemia factor 2   14.0
# 4                                      Leukemia cells   13.0
# ..                                                ...    ...
# 58                Runt-related transcription factor 2    5.0
# 59                        MLL1-ASH2L/RbBP5/WDR5/DPY30    5.0
# 60  Runt-related transcription factor 1/Core-bindi...    4.0
# 61  Baculoviral IAP repeat-containing protein 2/BC...    4.0
# 62           E3 ubiquitin-protein ligase XIAP/BCR/ABL    4.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL1864
# 1                False    CHEMBL1075309
# 2                False    CHEMBL1293256
# 3                False    CHEMBL4295830
# 4                False     CHEMBL614844
# ..                 ...              ...
# 58               False    CHEMBL1681609
# 59               False    CHEMBL4106124
# 60               False    CHEMBL2093862
# 61               False    CHEMBL4296119
# 62               False    CHEMBL4296120
#
#                                     target_components  \
# 0   [{'accession': 'P40238', 'component_descriptio...
# 1   [{'accession': 'Q08351', 'component_descriptio...
# 2   [{'accession': 'P40225', 'component_descriptio...
# 3   [{'accession': 'Q15773', 'component_descriptio...
# 4                                                  []
# ..                                                ...
# 58  [{'accession': 'Q08775', 'component_descriptio...
# 59  [{'accession': 'P61964', 'component_descriptio...
# 60  [{'accession': 'Q01196', 'component_descriptio...
# 61  [{'accession': 'P00519', 'component_descriptio...
# 62  [{'accession': 'P00519', 'component_descriptio...
#
#                     target_type   tax_id
# 0                SINGLE PROTEIN   9606.0
# 1                SINGLE PROTEIN  10090.0
# 2                SINGLE PROTEIN   9606.0
# 3                SINGLE PROTEIN   9606.0
# 4                     CELL-LINE   9606.0
# ..                          ...      ...
# 58               SINGLE PROTEIN  10090.0
# 59  PROTEIN-PROTEIN INTERACTION   9606.0
# 60  PROTEIN-PROTEIN INTERACTION   9606.0
# 61  PROTEIN-PROTEIN INTERACTION   9606.0
# 62  PROTEIN-PROTEIN INTERACTION   9606.0
#
# [63 rows x 9 columns]

# %% [markdown]
# ## Select and retrieve bioactivity data for Myeloproliferative leukemia

# %%
# I will assign the 1st index entry (which corresponds to the target protien, Thrombopoietin receptor) -
# to the selected_target variable. 
selected_target = targets.target_chembl_id[0]
selected_target

# CHEMBL1864 is a unique id of the target
# Out:
# 'CHEMBL1864'

# %%
# Here i will retrieve only bioactivity data for Myeloproliferative leukemia(CHEMBL1864) that are reported as-
# IC50 values in nM(nanomolar) unit.

# define new variable
activity = new_client.activity

# this will select only the values containing IC50 for the column called standard type
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="EC50")

# %%
# make a dataframe and assign it res and print the content
pd.set_option('display.max_columns', None)

df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      1184334                  []    CHEMBL815867
# 1             None      1187111                  []    CHEMBL815867
# 2             None      1187113                  []    CHEMBL815867
# 3             None      1188428                  []    CHEMBL815867
# 4             None      1188430                  []    CHEMBL815867
#
#                                    assay_description assay_type  \
# 0  Effective concentration for thrombopoietin luc...          B
# 1  Effective concentration for thrombopoietin luc...          B
# 2  Effective concentration for thrombopoietin luc...          B
# 3  Effective concentration for thrombopoietin luc...          B
# 4  Effective concentration for thrombopoietin luc...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000188  BAO_0000219
# 1                    None                   None  BAO_0000188  BAO_0000219
# 2                    None                   None  BAO_0000188  BAO_0000219
# 3                    None                   None  BAO_0000188  BAO_0000219
# 4                    None                   None  BAO_0000188  BAO_0000219
#
#            bao_label                                   canonical_smiles  \
# 0  cell-based format  Cc1[nH]n(-c2ccc([N+](=O)[O-])cc2)c(=O)c1/N=N/c...
# 1  cell-based format  O=S(=O)(O)c1cc(O)c(/N=N/c2c(O)ccc3cc(O)ccc23)c...
# 2  cell-based format  Cc1[nH]n(-c2ccc(C(C)C)cc2)c(=O)c1/N=N/c1c(O)cc...
# 3  cell-based format  O=S(=O)(O)c1cc(O)c(/N=N/c2c(O)c(O)cc3ccccc23)c...
# 4  cell-based format  CCNS(=O)(=O)c1cccc(-n2[nH]c(C)c(/N=N/c3c(O)cc(...
#
#   data_validity_comment data_validity_description document_chembl_id  \
# 0                  None                      None      CHEMBL1134668
# 1                  None                      None      CHEMBL1134668
# 2                  None                      None      CHEMBL1134668
# 3                  None                      None      CHEMBL1134668
# 4                  None                      None      CHEMBL1134668
#
#   document_journal  document_year  \
# 0    J. Med. Chem.           2001
# 1    J. Med. Chem.           2001
# 2    J. Med. Chem.           2001
# 3    J. Med. Chem.           2001
# 4    J. Med. Chem.           2001
#
#                                    ligand_efficiency molecule_chembl_id  \
# 0  {'bei': '13.63', 'le': '0.26', 'lle': '2.50', ...      CHEMBL3144682
# 1  {'bei': '13.89', 'le': '0.27', 'lle': '0.93', ...       CHEMBL125996
# 2  {'bei': '15.34', 'le': '0.30', 'lle': '2.03', ...      CHEMBL3144783
# 3  {'bei': '13.89', 'le': '0.27', 'lle': '0.93', ...       CHEMBL122504
# 4  {'bei': '9.41', 'le': '0.19', 'lle': '1.71', '...      CHEMBL3144667
#
#   molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0               None             CHEMBL3144682          6.40
# 1               None              CHEMBL125996          5.70
# 2               None             CHEMBL3144783          7.16
# 3               None              CHEMBL122504          5.70
# 4               None             CHEMBL3144667          5.00
#
#    potential_duplicate                                 qudt_units  record_id  \
# 0                    0  http://www.openphacts.org/units/Nanomolar     234728
# 1                    0  http://www.openphacts.org/units/Nanomolar     234684
# 2                    0  http://www.openphacts.org/units/Nanomolar     234726
# 3                    0  http://www.openphacts.org/units/Nanomolar     234736
# 4                    0  http://www.openphacts.org/units/Nanomolar     234722
#
#   relation  src_id  standard_flag standard_relation standard_text_value  \
# 0        =       1              1                 =                None
# 1        =       1              1                 =                None
# 2        =       1              1                 =                None
# 3        =       1              1                 =                None
# 4        =       1              1                 =                None
#
#   standard_type standard_units standard_upper_value standard_value  \
# 0          EC50             nM                 None          400.0
# 1          EC50             nM                 None         2000.0
# 2          EC50             nM                 None           70.0
# 3          EC50             nM                 None         2000.0
# 4          EC50             nM                 None        10000.0
#
#   target_chembl_id target_organism         target_pref_name target_tax_id  \
# 0       CHEMBL1864    Homo sapiens  Thrombopoietin receptor          9606
# 1       CHEMBL1864    Homo sapiens  Thrombopoietin receptor          9606
# 2       CHEMBL1864    Homo sapiens  Thrombopoietin receptor          9606
# 3       CHEMBL1864    Homo sapiens  Thrombopoietin receptor          9606
# 4       CHEMBL1864    Homo sapiens  Thrombopoietin receptor          9606
#
#   text_value  toid  type units    uo_units upper_value value
# 0       None  None  EC50    uM  UO_0000065        None   0.4
# 1       None  None  EC50    uM  UO_0000065        None   2.0
# 2       None  None  EC50    uM  UO_0000065        None  0.07
# 3       None  None  EC50    uM  UO_0000065        None   2.0
# 4       None  None  EC50    uM  UO_0000065        None  10.0

# %%
# making sure that the standard_type column only has EC50
# when i define a particular standard type here, it will make my data set more uniform.
df['standard_type']
# Out:
# 0      EC50
# 1      EC50
# 2      EC50
# 3      EC50
# 4      EC50
#        ...
# 327    EC50
# 328    EC50
# 329    EC50
# 330    EC50
# 331    EC50
# Name: standard_type, Length: 332, dtype: object

# %%
# the standard_value column is the potency of the drug. the number represents the potency. the lower the number, the better the potency of the drug becomes. the higher the number, the worse the potency becomes.

# ideally i want this number to be the lowest it can be. meaning that the inhibitory conentration at 50% will have a low concentration, meaning that in order to elicit 50% of the inhibition of a target protien, i would need lower concentration of the drug.

df['standard_value']
# Out:
# 0        400.0
# 1       2000.0
# 2         70.0
# 3       2000.0
# 4      10000.0
#         ...
# 327       22.0
# 328       31.0
# 329       26.0
# 330       42.0
# 331       46.0
# Name: standard_value, Length: 332, dtype: object

# %%
# finally i will save the resulting bioactivity data to a CSV file called bioactivity_data.csv
df.to_csv('data/bioactivity_data.csv', index=False)

# %% [markdown]
# # Handling missing data
# If any compounds have missing values for the standard_value column, then drop it.

# %%
df2 = pd.read_csv('data/bioactivity_data.csv')

# %%
df2 = df2[df2.standard_value.notna()]
df2
# there is no missing values for this data set.
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                NaN      1184334                  []    CHEMBL815867
# 1                NaN      1187111                  []    CHEMBL815867
# 2                NaN      1187113                  []    CHEMBL815867
# 3                NaN      1188428                  []    CHEMBL815867
# 4                NaN      1188430                  []    CHEMBL815867
# ..               ...          ...                 ...             ...
# 327              NaN      3499609                  []   CHEMBL1260125
# 328              NaN      3499610                  []   CHEMBL1260125
# 329              NaN      3499611                  []   CHEMBL1260125
# 330              NaN      3499612                  []   CHEMBL1260125
# 331              NaN      3499613                  []   CHEMBL1260125
#
#                                      assay_description assay_type  \
# 0    Effective concentration for thrombopoietin luc...          B
# 1    Effective concentration for thrombopoietin luc...          B
# 2    Effective concentration for thrombopoietin luc...          B
# 3    Effective concentration for thrombopoietin luc...          B
# 4    Effective concentration for thrombopoietin luc...          B
# ..                                                 ...        ...
# 327  Inhibition of human TPOR expressed in human Ba...          B
# 328  Inhibition of human TPOR expressed in human Ba...          B
# 329  Inhibition of human TPOR expressed in human Ba...          B
# 330  Inhibition of human TPOR expressed in human Ba...          B
# 331  Inhibition of human TPOR expressed in human Ba...          B
#
#      assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0                        NaN                     NaN  BAO_0000188
# 1                        NaN                     NaN  BAO_0000188
# 2                        NaN                     NaN  BAO_0000188
# 3                        NaN                     NaN  BAO_0000188
# 4                        NaN                     NaN  BAO_0000188
# ..                       ...                     ...          ...
# 327                      NaN                     NaN  BAO_0000188
# 328                      NaN                     NaN  BAO_0000188
# 329                      NaN                     NaN  BAO_0000188
# 330                      NaN                     NaN  BAO_0000188
# 331                      NaN                     NaN  BAO_0000188
#
#       bao_format          bao_label  \
# 0    BAO_0000219  cell-based format
# 1    BAO_0000219  cell-based format
# 2    BAO_0000219  cell-based format
# 3    BAO_0000219  cell-based format
# 4    BAO_0000219  cell-based format
# ..           ...                ...
# 327  BAO_0000219  cell-based format
# 328  BAO_0000219  cell-based format
# 329  BAO_0000219  cell-based format
# 330  BAO_0000219  cell-based format
# 331  BAO_0000219  cell-based format
#
#                                       canonical_smiles  data_validity_comment  \
# 0    Cc1[nH]n(-c2ccc([N+](=O)[O-])cc2)c(=O)c1/N=N/c...                    NaN
# 1    O=S(=O)(O)c1cc(O)c(/N=N/c2c(O)ccc3cc(O)ccc23)c...                    NaN
# 2    Cc1[nH]n(-c2ccc(C(C)C)cc2)c(=O)c1/N=N/c1c(O)cc...                    NaN
# 3    O=S(=O)(O)c1cc(O)c(/N=N/c2c(O)c(O)cc3ccccc23)c...                    NaN
# 4    CCNS(=O)(=O)c1cccc(-n2[nH]c(C)c(/N=N/c3c(O)cc(...                    NaN
# ..                                                 ...                    ...
# 327  CNC(=O)c1ccc2c(c1)CCN2C(=S)NN/C(C)=C1\C(=O)N(c...                    NaN
# 328  CC1=NN(c2ccc(C)c(C)c2)C(=O)/C1=C(/C)NNC(=S)N1C...                    NaN
# 329  CCNC(=O)c1ccc2c(c1)CCN2C(=S)NN/C(C)=C1\C(=O)N(...                    NaN
# 330  CC1=NN(c2ccc(C)c(C)c2)C(=O)/C1=C(/C)NNC(=O)N1C...                    NaN
# 331  CC1=NN(c2ccc3c(c2)CCC3)C(=O)/C1=C(/C)NNC(=O)N1...                    NaN
#
#      data_validity_description document_chembl_id          document_journal  \
# 0                          NaN      CHEMBL1134668             J. Med. Chem.
# 1                          NaN      CHEMBL1134668             J. Med. Chem.
# 2                          NaN      CHEMBL1134668             J. Med. Chem.
# 3                          NaN      CHEMBL1134668             J. Med. Chem.
# 4                          NaN      CHEMBL1134668             J. Med. Chem.
# ..                         ...                ...                       ...
# 327                        NaN      CHEMBL1255541  Bioorg. Med. Chem. Lett.
# 328                        NaN      CHEMBL1255541  Bioorg. Med. Chem. Lett.
# 329                        NaN      CHEMBL1255541  Bioorg. Med. Chem. Lett.
# 330                        NaN      CHEMBL1255541  Bioorg. Med. Chem. Lett.
# 331                        NaN      CHEMBL1255541  Bioorg. Med. Chem. Lett.
#
#      document_year                                  ligand_efficiency  \
# 0             2001  {'bei': '13.63', 'le': '0.26', 'lle': '2.50', ...
# 1             2001  {'bei': '13.89', 'le': '0.27', 'lle': '0.93', ...
# 2             2001  {'bei': '15.34', 'le': '0.30', 'lle': '2.03', ...
# 3             2001  {'bei': '13.89', 'le': '0.27', 'lle': '0.93', ...
# 4             2001  {'bei': '9.41', 'le': '0.19', 'lle': '1.71', '...
# ..             ...                                                ...
# 327           2010  {'bei': '16.07', 'le': '0.31', 'lle': '4.56', ...
# 328           2010  {'bei': '14.10', 'le': '0.27', 'lle': '4.30', ...
# 329           2010  {'bei': '15.46', 'le': '0.30', 'lle': '4.10', ...
# 330           2010  {'bei': '16.48', 'le': '0.31', 'lle': '4.10', ...
# 331           2010  {'bei': '15.97', 'le': '0.29', 'lle': '4.19', ...
#
#     molecule_chembl_id molecule_pref_name parent_molecule_chembl_id  \
# 0        CHEMBL3144682                NaN             CHEMBL3144682
# 1         CHEMBL125996                NaN              CHEMBL125996
# 2        CHEMBL3144783                NaN             CHEMBL3144783
# 3         CHEMBL122504                NaN              CHEMBL122504
# 4        CHEMBL3144667                NaN             CHEMBL3144667
# ..                 ...                ...                       ...
# 327      CHEMBL1257846                NaN             CHEMBL1257846
# 328      CHEMBL1257847                NaN             CHEMBL1257847
# 329      CHEMBL1257962                NaN             CHEMBL1257962
# 330      CHEMBL1257963                NaN             CHEMBL1257963
# 331      CHEMBL1258074                NaN             CHEMBL1258074
#
#      pchembl_value  potential_duplicate  \
# 0             6.40                    0
# 1             5.70                    0
# 2             7.16                    0
# 3             5.70                    0
# 4             5.00                    0
# ..             ...                  ...
# 327           7.66                    0
# 328           7.51                    0
# 329           7.58                    0
# 330           7.38                    0
# 331           7.34                    0
#
#                                     qudt_units  record_id relation  src_id  \
# 0    http://www.openphacts.org/units/Nanomolar     234728        =       1
# 1    http://www.openphacts.org/units/Nanomolar     234684        =       1
# 2    http://www.openphacts.org/units/Nanomolar     234726        =       1
# 3    http://www.openphacts.org/units/Nanomolar     234736        =       1
# 4    http://www.openphacts.org/units/Nanomolar     234722        =       1
# ..                                         ...        ...      ...     ...
# 327  http://www.openphacts.org/units/Nanomolar     962762        =       1
# 328  http://www.openphacts.org/units/Nanomolar     962763        =       1
# 329  http://www.openphacts.org/units/Nanomolar     962892        =       1
# 330  http://www.openphacts.org/units/Nanomolar     962893        =       1
# 331  http://www.openphacts.org/units/Nanomolar     963017        =       1
#
#      standard_flag standard_relation  standard_text_value standard_type  \
# 0                1                 =                  NaN          EC50
# 1                1                 =                  NaN          EC50
# 2                1                 =                  NaN          EC50
# 3                1                 =                  NaN          EC50
# 4                1                 =                  NaN          EC50
# ..             ...               ...                  ...           ...
# 327              1                 =                  NaN          EC50
# 328              1                 =                  NaN          EC50
# 329              1                 =                  NaN          EC50
# 330              1                 =                  NaN          EC50
# 331              1                 =                  NaN          EC50
#
#     standard_units  standard_upper_value  standard_value target_chembl_id  \
# 0               nM                   NaN           400.0       CHEMBL1864
# 1               nM                   NaN          2000.0       CHEMBL1864
# 2               nM                   NaN            70.0       CHEMBL1864
# 3               nM                   NaN          2000.0       CHEMBL1864
# 4               nM                   NaN         10000.0       CHEMBL1864
# ..             ...                   ...             ...              ...
# 327             nM                   NaN            22.0       CHEMBL1864
# 328             nM                   NaN            31.0       CHEMBL1864
# 329             nM                   NaN            26.0       CHEMBL1864
# 330             nM                   NaN            42.0       CHEMBL1864
# 331             nM                   NaN            46.0       CHEMBL1864
#
#     target_organism         target_pref_name  target_tax_id  text_value  toid  \
# 0      Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 1      Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 2      Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 3      Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 4      Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# ..              ...                      ...            ...         ...   ...
# 327    Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 328    Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 329    Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 330    Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
# 331    Homo sapiens  Thrombopoietin receptor           9606         NaN   NaN
#
#      type units    uo_units  upper_value  value
# 0    EC50    uM  UO_0000065          NaN   0.40
# 1    EC50    uM  UO_0000065          NaN   2.00
# 2    EC50    uM  UO_0000065          NaN   0.07
# 3    EC50    uM  UO_0000065          NaN   2.00
# 4    EC50    uM  UO_0000065          NaN  10.00
# ..    ...   ...         ...          ...    ...
# 327  EC50    nM  UO_0000065          NaN  22.00
# 328  EC50    nM  UO_0000065          NaN  31.00
# 329  EC50    nM  UO_0000065          NaN  26.00
# 330  EC50    nM  UO_0000065          NaN  42.00
# 331  EC50    nM  UO_0000065          NaN  46.00
#
# [328 rows x 45 columns]

# %% [markdown]
# ## Data pre-processing of the bioactivity data
#
# Here i will label compounds as either being active, inactive, or intermediate.
#
# The bioactivity data is in the EC50 unit. Compounds having values less than 1000nM will be considered to be active. Those greater than 10,000nM will be considered to be inactive. As for those in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
# For the benefit of creating machine learning models where i can classify compounds into 3 categories as either being active compound, inactive compound, intermediate compound.

bioactivity_class = []

for i in df2.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append('inactive')
    elif float(i) <= 1000:
        bioactivity_class.append('active')
    else:
         bioactivity_class.append('intermediate')

# %%
# Iterate over the molecule_chembl_id to a list:
# this will go through the molecule id's and put them in the mol_cid variable.
# since this dataset contains a lot of molecular structres(Drug compounds), I need to keep them for future analysis.
# These drugs will act on the target protein to get the desired benefits of the medication.
mol_cid = []
for i in df2.molecule_chembl_id:
    mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL3144682',
#  'CHEMBL125996',
#  'CHEMBL3144783',
#  'CHEMBL122504',
#  'CHEMBL3144667',
#  'CHEMBL3144785',
#  'CHEMBL3144672',
#  'CHEMBL3144775',
#  'CHEMBL3144679',
#  'CHEMBL340040',
#  'CHEMBL3144788',
#  'CHEMBL3144786',
#  'CHEMBL3144789',
#  'CHEMBL124367',
#  'CHEMBL3144776',
#  'CHEMBL3144677',
#  'CHEMBL121918',
#  'CHEMBL3144778',
#  'CHEMBL3144665',
#  'CHEMBL3144780',
#  'CHEMBL3144666',
#  'CHEMBL3144790',
#  'CHEMBL3144676',
#  'CHEMBL3144836',
#  'CHEMBL3144675',
#  'CHEMBL3144787',
#  'CHEMBL3144670',
#  'CHEMBL3144781',
#  'CHEMBL3144668',
#  'CHEMBL3144663',
#  'CHEMBL3144664',
#  'CHEMBL3144844',
#  'CHEMBL445374',
#  'CHEMBL331220',
#  'CHEMBL124855',
#  'CHEMBL123373',
#  'CHEMBL3144662',
#  'CHEMBL3144661',
#  'CHEMBL3144852',
#  'CHEMBL3144669',
#  'CHEMBL3144680',
#  'CHEMBL121996',
#  'CHEMBL420168',
#  'CHEMBL3144784',
#  'CHEMBL122867',
#  'CHEMBL426663',
#  'CHEMBL204667',
#  'CHEMBL380407',
#  'CHEMBL377292',
#  'CHEMBL202796',
#  'CHEMBL382806',
#  'CHEMBL205027',
#  'CHEMBL206304',
#  'CHEMBL204160',
#  'CHEMBL206393',
#  'CHEMBL247013',
#  'CHEMBL397519',
#  'CHEMBL247645',
#  'CHEMBL247644',
#  'CHEMBL393087',
#  'CHEMBL248192',
#  'CHEMBL248006',
#  'CHEMBL248004',
#  'CHEMBL391597',
#  'CHEMBL247822',
#  'CHEMBL247643',
#  'CHEMBL247642',
#  'CHEMBL247641',
#  'CHEMBL247461',
#  'CHEMBL248189',
#  'CHEMBL247820',
#  'CHEMBL247818',
#  'CHEMBL428227',
#  'CHEMBL393268',
#  'CHEMBL247431',
#  'CHEMBL247607',
#  'CHEMBL247606',
#  'CHEMBL247605',
#  'CHEMBL247041',
#  'CHEMBL247040',
#  'CHEMBL395701',
#  'CHEMBL428226',
#  'CHEMBL249063',
#  'CHEMBL249062',
#  'CHEMBL249061',
#  'CHEMBL398549',
#  'CHEMBL401276',
#  'CHEMBL247655',
#  'CHEMBL248237',
#  'CHEMBL245995',
#  'CHEMBL399136',
#  'CHEMBL245994',
#  'CHEMBL245993',
#  'CHEMBL246619',
#  'CHEMBL246618',
#  'CHEMBL246617',
#  'CHEMBL398286',
#  'CHEMBL246616',
#  'CHEMBL400559',
#  'CHEMBL248035',
#  'CHEMBL245795',
#  'CHEMBL399357',
#  'CHEMBL248390',
#  'CHEMBL248389',
#  'CHEMBL248388',
#  'CHEMBL399356',
#  'CHEMBL248218',
#  'CHEMBL248217',
#  'CHEMBL248042',
#  'CHEMBL440231',
#  'CHEMBL248041',
#  'CHEMBL247019',
#  'CHEMBL247017',
#  'CHEMBL246847',
#  'CHEMBL246846',
#  'CHEMBL245794',
#  'CHEMBL245793',
#  'CHEMBL247642',
#  'CHEMBL245792',
#  'CHEMBL248216',
#  'CHEMBL248215',
#  'CHEMBL399767',
#  'CHEMBL248039',
#  'CHEMBL438874',
#  'CHEMBL247016',
#  'CHEMBL247015',
#  'CHEMBL247014',
#  'CHEMBL246844',
#  'CHEMBL246843',
#  'CHEMBL400741',
#  'CHEMBL248213',
#  'CHEMBL248211',
#  'CHEMBL248037',
#  'CHEMBL398466',
#  'CHEMBL247650',
#  'CHEMBL247240',
#  'CHEMBL249672',
#  'CHEMBL442278',
#  'CHEMBL249471',
#  'CHEMBL246429',
#  'CHEMBL246428',
#  'CHEMBL248434',
#  'CHEMBL248428',
#  'CHEMBL436633',
#  'CHEMBL248426',
#  'CHEMBL246421',
#  'CHEMBL399074',
#  'CHEMBL246197',
#  'CHEMBL246196',
#  'CHEMBL399073',
#  'CHEMBL248399',
#  'CHEMBL399768',
#  'CHEMBL248242',
#  'CHEMBL400195',
#  'CHEMBL248241',
#  'CHEMBL248055',
#  'CHEMBL439406',
#  'CHEMBL248054',
#  'CHEMBL248053',
#  'CHEMBL398287',
#  'CHEMBL400869',
#  'CHEMBL248047',
#  'CHEMBL248046',
#  'CHEMBL247198',
#  'CHEMBL438148',
#  'CHEMBL248026',
#  'CHEMBL429295',
#  'CHEMBL428226',
#  'CHEMBL247822',
#  'CHEMBL247431',
#  'CHEMBL399136',
#  'CHEMBL251095',
#  'CHEMBL247013',
#  'CHEMBL258532',
#  'CHEMBL405683',
#  'CHEMBL260846',
#  'CHEMBL405203',
#  'CHEMBL262855',
#  'CHEMBL261539',
#  'CHEMBL405478',
#  'CHEMBL263109',
#  'CHEMBL408853',
#  'CHEMBL412807',
#  'CHEMBL261023',
#  'CHEMBL399357',
#  'CHEMBL409092',
#  'CHEMBL260089',
#  'CHEMBL409504',
#  'CHEMBL247644',
#  'CHEMBL247643',
#  'CHEMBL247645',
#  'CHEMBL247822',
#  'CHEMBL393087',
#  'CHEMBL247642',
#  'CHEMBL247606',
#  'CHEMBL245993',
#  'CHEMBL428227',
#  'CHEMBL248237',
#  'CHEMBL428226',
#  'CHEMBL246619',
#  'CHEMBL249063',
#  'CHEMBL246618',
#  'CHEMBL399136',
#  'CHEMBL246617',
#  'CHEMBL247431',
#  'CHEMBL245994',
#  'CHEMBL249061',
#  'CHEMBL398286',
#  'CHEMBL248006',
#  'CHEMBL247818',
#  'CHEMBL393268',
#  'CHEMBL247607',
#  'CHEMBL249062',
#  'CHEMBL246616',
#  'CHEMBL400559',
#  'CHEMBL248035',
#  'CHEMBL461101',
#  'CHEMBL477195',
#  'CHEMBL525906',
#  'CHEMBL496950',
#  'CHEMBL496122',
#  'CHEMBL496123',
#  'CHEMBL522391',
#  'CHEMBL525732',
#  'CHEMBL497372',
#  'CHEMBL497582',
#  'CHEMBL497583',
#  'CHEMBL525533',
#  'CHEMBL497793',
#  'CHEMBL522070',
#  'CHEMBL496755',
#  'CHEMBL495731',
#  'CHEMBL497348',
#  'CHEMBL526077',
#  'CHEMBL497349',
#  'CHEMBL498581',
#  'CHEMBL498173',
#  'CHEMBL497149',
#  'CHEMBL429295',
#  'CHEMBL523975',
#  'CHEMBL465957',
#  'CHEMBL462874',
#  'CHEMBL516993',
#  'CHEMBL461174',
#  'CHEMBL524116',
#  'CHEMBL490096',
#  'CHEMBL489309',
#  'CHEMBL523097',
#  'CHEMBL518057',
#  'CHEMBL455445',
#  'CHEMBL455654',
#  'CHEMBL459474',
#  'CHEMBL459687',
#  'CHEMBL461974',
#  'CHEMBL461975',
#  'CHEMBL462144',
#  'CHEMBL463814',
#  'CHEMBL461100',
#  'CHEMBL490409',
#  'CHEMBL490410',
#  'CHEMBL522280',
#  'CHEMBL490411',
#  'CHEMBL490412',
#  'CHEMBL489388',
#  'CHEMBL522978',
#  'CHEMBL491798',
#  'CHEMBL490585',
#  'CHEMBL490586',
#  'CHEMBL523460',
#  'CHEMBL523147',
#  'CHEMBL521797',
#  'CHEMBL448025',
#  'CHEMBL491804',
#  'CHEMBL521768',
#  'CHEMBL489365',
#  'CHEMBL489366',
#  'CHEMBL521746',
#  'CHEMBL489367',
#  'CHEMBL492017',
#  'CHEMBL477174',
#  'CHEMBL477175',
#  'CHEMBL477381',
#  'CHEMBL515795',
#  'CHEMBL476556',
#  'CHEMBL479081',
#  'CHEMBL518285',
#  'CHEMBL479082',
#  'CHEMBL479083',
#  'CHEMBL477195',
#  'CHEMBL477400',
#  'CHEMBL477401',
#  'CHEMBL516272',
#  'CHEMBL479093',
#  'CHEMBL514557',
#  'CHEMBL461101',
#  'CHEMBL523975',
#  'CHEMBL1171609',
#  'CHEMBL1171610',
#  'CHEMBL1170611',
#  'CHEMBL1172354',
#  'CHEMBL1172355',
#  'CHEMBL1171783',
#  'CHEMBL1171784',
#  'CHEMBL1169646',
#  'CHEMBL1169647',
#  'CHEMBL1169815',
#  'CHEMBL1172356',
#  'CHEMBL1170598',
#  'CHEMBL1170599',
#  'CHEMBL1170600',
#  'CHEMBL1169816',
#  'CHEMBL1170003',
#  'CHEMBL1170004',
#  'CHEMBL1170197',
#  'CHEMBL1222569',
#  'CHEMBL1222639',
#  'CHEMBL1222640',
#  'CHEMBL1222641',
#  'CHEMBL1222642',
#  'CHEMBL1257603',
#  'CHEMBL1257604',
#  'CHEMBL1257723',
#  'CHEMBL1257724',
#  'CHEMBL1257846',
#  'CHEMBL1257847',
#  'CHEMBL1257962',
#  'CHEMBL1257963',
#  'CHEMBL1258074']

# %%
# Iterate canonical_smiles to a list:
canonical_smiles = []
for i in df2.canonical_smiles:
    canonical_smiles.append(i)

# %%
# Iterate standard_value to a list:
standard_value = []
for i in df2.standard_value:
    standard_value.append(i)

# %%
# Combine the 4 lists into a dataframe
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame(data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3144682  Cc1[nH]n(-c2ccc([N+](=O)[O-])cc2)c(=O)c1/N=N/c...
# 1         CHEMBL125996  O=S(=O)(O)c1cc(O)c(/N=N/c2c(O)ccc3cc(O)ccc23)c...
# 2        CHEMBL3144783  Cc1[nH]n(-c2ccc(C(C)C)cc2)c(=O)c1/N=N/c1c(O)cc...
# 3         CHEMBL122504  O=S(=O)(O)c1cc(O)c(/N=N/c2c(O)c(O)cc3ccccc23)c...
# 4        CHEMBL3144667  CCNS(=O)(=O)c1cccc(-n2[nH]c(C)c(/N=N/c3c(O)cc(...
# ..                 ...                                                ...
# 323      CHEMBL1257846  CNC(=O)c1ccc2c(c1)CCN2C(=S)NN/C(C)=C1\C(=O)N(c...
# 324      CHEMBL1257847  CC1=NN(c2ccc(C)c(C)c2)C(=O)/C1=C(/C)NNC(=S)N1C...
# 325      CHEMBL1257962  CCNC(=O)c1ccc2c(c1)CCN2C(=S)NN/C(C)=C1\C(=O)N(...
# 326      CHEMBL1257963  CC1=NN(c2ccc(C)c(C)c2)C(=O)/C1=C(/C)NNC(=O)N1C...
# 327      CHEMBL1258074  CC1=NN(c2ccc3c(c2)CCC3)C(=O)/C1=C(/C)NNC(=O)N1...
#
#     bioactivity_class  standard_value
# 0              active           400.0
# 1        intermediate          2000.0
# 2              active            70.0
# 3        intermediate          2000.0
# 4            inactive         10000.0
# ..                ...             ...
# 323            active            22.0
# 324            active            31.0
# 325            active            26.0
# 326            active            42.0
# 327            active            46.0
#
# [328 rows x 4 columns]

# %%
# save pre-processed dataframe to CSV file
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)
